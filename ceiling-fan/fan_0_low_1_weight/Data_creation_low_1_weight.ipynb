# %% [markdown]
# This notebook is for collating the fan acceleromter records into one file for further data analysis.The 3 axis accelerometer has 3 set of readings.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data_0 = pd.read_csv("0000.csv", header = None)

# %%
data_0.head()
# Out:
#           0         1         2
# 0 -0.019043  0.201660  0.974609
# 1 -0.019043  0.189453  0.975586
# 2 -0.018555  0.192871  0.982422
# 3 -0.020508  0.192383  0.979004
# 4 -0.020996  0.193359  0.976563

# %%
data_0.shape
# Out:
# (200, 3)

# %%
data_0.columns = ['x', 'y' , 'z']

# %%
plt.scatter(data_0.x, data_0.y)

# %%
plt.scatter(data_0.x, data_0.z)

# %%
plt.scatter(data_0.y, data_0.z)

# %%
## no of file - 579
## 200 records each 
## weight = 1 
## speed = low  - 0

# %%
speed = 0 ## for 'low'
weight = 1
no_of_files = 579
no_of_chars = 4

# %%
df = pd.DataFrame()

x = np.empty(1)
y = np.empty(1)
z = np.empty(1)
for i in range(no_of_files):
    file_name = str(i).zfill(no_of_chars) + '.csv'
    data = pd.read_csv(file_name , header = None)
    data.columns = ['x', 'y', 'z']
    data['count'] = i
    df = df.append(data, ignore_index = True)

print(df.shape)
# Out:
# (115800, 4)

# %%
df['weight'] =1
df['speed'] = 0  ## for low speed

# %%
df.tail()
# Out:
#                x         y         z  count  weight  speed
# 115795 -0.026367  0.187988  0.977539    578       1      0
# 115796 -0.015625  0.196777  0.977051    578       1      0
# 115797 -0.019531  0.200195  0.980469    578       1      0
# 115798 -0.022461  0.187988  0.981934    578       1      0
# 115799 -0.017090  0.195801  0.977051    578       1      0

# %%
name_of_final_file = 'fan_0_weight_' + str(weight) + '_' + 'speed_' + str(speed) +'.csv'
name_of_final_file
# Out:
# 'fan_0_weight_1_speed_0.csv'

# %%
## save the file 
df.to_csv(name_of_final_file , index = False)

# %%
temp = pd.read_csv(name_of_final_file)

# %%
temp.shape
# Out:
# (115800, 6)

# %%
temp.tail()
# Out:
#                x         y         z  count  weight  speed
# 115795 -0.026367  0.187988  0.977539    578       1      0
# 115796 -0.015625  0.196777  0.977051    578       1      0
# 115797 -0.019531  0.200195  0.980469    578       1      0
# 115798 -0.022461  0.187988  0.981934    578       1      0
# 115799 -0.017090  0.195801  0.977051    578       1      0
