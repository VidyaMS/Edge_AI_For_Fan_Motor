# %% [markdown]
# This notebook is for collating the fan acceleromter records into one file for further data analysis.The 3 axis accelerometer has 3 set of readings.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data_0 = pd.read_csv("0000.csv", header = None)

# %%
data_0.head()
# Out:
#           0         1         2
# 0 -0.056641  0.228516  0.965820
# 1 -0.011719  0.234863  0.971680
# 2 -0.081543  0.199707  0.964844
# 3  0.000977  0.261719  0.997559
# 4 -0.068359  0.203613  0.965820

# %%
data_0.shape
# Out:
# (200, 3)

# %%
data_0.columns = ['x', 'y' , 'z']

# %%
plt.scatter(data_0.x, data_0.y)

# %%
plt.scatter(data_0.x, data_0.z)

# %%
plt.scatter(data_0.y, data_0.z)

# %%
## no of file - 584
## 200 records each 
## weight = 1 
## speed = high  - 2

# %%
speed = 2 ## for 'high'
weight = 1
no_of_files = 584
no_of_chars = 4

# %%
df = pd.DataFrame()

x = np.empty(1)
y = np.empty(1)
z = np.empty(1)
for i in range(no_of_files):
    file_name = str(i).zfill(no_of_chars) + '.csv'
    data = pd.read_csv(file_name , header = None)
    data.columns = ['x', 'y', 'z']
    data['count'] = i
    df = df.append(data, ignore_index = True)

print(df.shape)
# Out:
# (116800, 4)

# %%
df['weight'] =1
df['speed'] = 2  ## for high speed

# %%
df.tail()
# Out:
#                x         y         z  count  weight  speed
# 116795 -0.049316  0.235352  0.980957    583       1      2
# 116796  0.000488  0.233398  0.976563    583       1      2
# 116797 -0.078613  0.190430  0.965332    583       1      2
# 116798  0.012207  0.274902  0.989258    583       1      2
# 116799 -0.067871  0.193848  0.963379    583       1      2

# %%
name_of_final_file = 'fan_0_weight_' + str(weight) + '_' + 'speed_' + str(speed) +'.csv'
name_of_final_file
# Out:
# 'fan_0_weight_1_speed_2.csv'

# %%
## save the file 
df.to_csv(name_of_final_file , index = False)

# %%
temp = pd.read_csv(name_of_final_file)

# %%
temp.shape
# Out:
# (116800, 6)

# %%
temp.tail()
# Out:
#                x         y         z  count  weight  speed
# 116795 -0.049316  0.235352  0.980957    583       1      2
# 116796  0.000488  0.233398  0.976563    583       1      2
# 116797 -0.078613  0.190430  0.965332    583       1      2
# 116798  0.012207  0.274902  0.989258    583       1      2
# 116799 -0.067871  0.193848  0.963379    583       1      2
