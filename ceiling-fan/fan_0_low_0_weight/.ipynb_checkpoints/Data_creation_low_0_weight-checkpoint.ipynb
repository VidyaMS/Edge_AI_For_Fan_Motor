# %% [markdown]
# This notebook is for collating the fan acceleromter records into one file for further data analysis.The 3 axis accelerometer has 3 set of readings.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data_0 = pd.read_csv("0000.csv", header = None)

# %%
data_0.head()
# Out:
#           0         1         2
# 0 -0.012695  0.203125  0.970703
# 1  0.000488  0.208008  0.979981
# 2 -0.027344  0.196289  0.984375
# 3  0.005371  0.217285  0.991699
# 4 -0.020020  0.199219  0.980469

# %%
data_0.shape
# Out:
# (200, 3)

# %%
data_0.columns = ['x', 'y' , 'z']

# %%
plt.scatter(data_0.x, data_0.y)

# %%
plt.scatter(data_0.x, data_0.z)

# %%
plt.scatter(data_0.y, data_0.z)

# %%
## no of file - 584
## 200 records each 
## weight = 0
## speed = low  - 0

# %%
speed = 0 ## for 'low'
weight = 0
no_of_files = 584
no_of_chars = 4

# %%
df = pd.DataFrame()

x = np.empty(1)
y = np.empty(1)
z = np.empty(1)
for i in range(no_of_files):
    file_name = str(i).zfill(no_of_chars) + '.csv'
    data = pd.read_csv(file_name , header = None)
    data.columns = ['x', 'y', 'z']
    data['count'] = i
    df = df.append(data, ignore_index = True)

print(df.shape)
# Out:
# (116800, 4)

# %%
df['weight'] =0
df['speed'] = 0  ## for low speed

# %%
df.tail()
# Out:
#                x         y         z  count  weight  speed
# 116795 -0.004883  0.211426  0.981934    583       0      0
# 116796 -0.013672  0.200195  0.979492    583       0      0
# 116797 -0.017090  0.202637  0.981934    583       0      0
# 116798 -0.004395  0.208008  0.981445    583       0      0
# 116799 -0.025879  0.198242  0.980957    583       0      0

# %%
name_of_final_file = 'fan_0_weight_' + str(weight) + '_' + 'speed_' + str(speed) +'.csv'
name_of_final_file
# Out:
# 'fan_0_weight_0_speed_0.csv'

# %%
## save the file 
df.to_csv(name_of_final_file , index = False)

# %%
temp = pd.read_csv(name_of_final_file)

# %%
temp.shape
# Out:
# (116800, 6)

# %%
temp.tail()
# Out:
#                x         y         z  count  weight  speed
# 116795 -0.004883  0.211426  0.981934    583       0      0
# 116796 -0.013672  0.200195  0.979492    583       0      0
# 116797 -0.017090  0.202637  0.981934    583       0      0
# 116798 -0.004395  0.208008  0.981445    583       0      0
# 116799 -0.025879  0.198242  0.980957    583       0      0
