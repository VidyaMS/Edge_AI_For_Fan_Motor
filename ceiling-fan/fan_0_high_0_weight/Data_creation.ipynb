# %% [markdown]
# This notebook is for collating the fan acceleromter records into one file for further data analysis.The 3 axis accelerometer has 3 set of readings.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data_0 = pd.read_csv("0000.csv", header = None)

# %%
data_0.head()
# Out:
#           0         1         2
# 0  0.047363  0.246094  0.973633
# 1 -0.065918  0.157227  0.959473
# 2  0.034180  0.248535  0.992676
# 3 -0.039063  0.196289  0.958008
# 4 -0.020020  0.217285  0.985840

# %%
data_0.shape
# Out:
# (200, 3)

# %%
data_0.columns = ['x', 'y' , 'z']

# %%
plt.scatter(data_0.x, data_0.y)

# %%
plt.scatter(data_0.x, data_0.z)

# %%
plt.scatter(data_0.y, data_0.z)

# %%
## no of file - 588 
## 200 records each 
## weight = 0 
## speed = high  - 2

# %%
speed = 2 
weight = 0
no_of_files = 589
no_of_chars = 4

# %%
df = pd.DataFrame()

x = np.empty(1)
y = np.empty(1)
z = np.empty(1)
for i in range(no_of_files):
    file_name = str(i).zfill(no_of_chars) + '.csv'
    data = pd.read_csv(file_name , header = None)
    data.columns = ['x', 'y', 'z']
    data['count'] = i
    df = df.append(data, ignore_index = True)

# %%
df.shape
# Out:
# (117800, 4)

# %%
df['weight'] =0
df['speed'] = 2  ## for high speed

# %%
df.tail()
# Out:
#                x         y         z  count  weight  speed
# 117795 -0.023438  0.196289  0.974121    588       0      2
# 117796 -0.030762  0.188477  0.983887    588       0      2
# 117797  0.024902  0.239258  0.980469    588       0      2
# 117798 -0.062500  0.157715  0.963867    588       0      2
# 117799  0.039063  0.239258  0.982910    588       0      2

# %%
name_of_final_file = 'fan_0_weight_' + str(weight) + '_' + 'speed_' + str(speed) +'.csv'
name_of_final_file
# Out:
# 'fan_0_weight_0_speed_2.csv'

# %%
## save the file 
df.to_csv(name_of_final_file , index = False)

# %%
temp = pd.read_csv(name_of_final_file)

# %%
temp.shape
# Out:
# (117800, 6)

# %%
temp.tail()
# Out:
#                x         y         z  count  weight  speed
# 117795 -0.023438  0.196289  0.974121    588       0      2
# 117796 -0.030762  0.188477  0.983887    588       0      2
# 117797  0.024902  0.239258  0.980469    588       0      2
# 117798 -0.062500  0.157715  0.963867    588       0      2
# 117799  0.039063  0.239258  0.982910    588       0      2
