# %% [markdown]
# This notebook is for collating the fan acceleromter records into one file for further data analysis.The 3 axis accelerometer has 3 set of readings.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data_0 = pd.read_csv("0000.csv", header = None)

# %%
data_0.head()
# Out:
#           0         1         2
# 0 -0.035156  0.183105  0.972168
# 1 -0.023438  0.199219  0.974121
# 2  0.001953  0.212402  0.990723
# 3 -0.041016  0.183105  0.963867
# 4  0.001953  0.220703  1.000000

# %%
data_0.shape
# Out:
# (200, 3)

# %%
data_0.columns = ['x', 'y' , 'z']

# %%
plt.scatter(data_0.x, data_0.y)

# %%
plt.scatter(data_0.x, data_0.z)

# %%
plt.scatter(data_0.y, data_0.z)

# %%
## no of file - 583
## 200 records each 
## weight = 1 
## speed = medium  - 1

# %%
speed = 1 ## for 'medium'
weight = 1
no_of_files = 583
no_of_chars = 4

# %%
df = pd.DataFrame()

x = np.empty(1)
y = np.empty(1)
z = np.empty(1)
for i in range(no_of_files):
    file_name = str(i).zfill(no_of_chars) + '.csv'
    data = pd.read_csv(file_name , header = None)
    data.columns = ['x', 'y', 'z']
    data['count'] = i
    df = df.append(data, ignore_index = True)

print(df.shape)
# Out:
# (116600, 4)

# %%
df['weight'] =1
df['speed'] = 1  ## for medium speed

# %%
df.tail()
# Out:
#                x         y         z  count  weight  speed
# 116595 -0.037598  0.190430  0.983887    582       1      1
# 116596 -0.002441  0.203613  0.991211    582       1      1
# 116597 -0.021484  0.190430  0.973633    582       1      1
# 116598 -0.014160  0.195313  0.982422    582       1      1
# 116599 -0.022949  0.198730  0.976563    582       1      1

# %%
name_of_final_file = 'fan_0_weight_' + str(weight) + '_' + 'speed_' + str(speed) +'.csv'
name_of_final_file
# Out:
# 'fan_0_weight_1_speed_1.csv'

# %%
## save the file 
df.to_csv(name_of_final_file , index = False)

# %%
temp = pd.read_csv(name_of_final_file)

# %%
temp.shape
# Out:
# (116600, 6)

# %%
temp.tail()
# Out:
#                x         y         z  count  weight  speed
# 116595 -0.037598  0.190430  0.983887    582       1      1
# 116596 -0.002441  0.203613  0.991211    582       1      1
# 116597 -0.021484  0.190430  0.973633    582       1      1
# 116598 -0.014160  0.195313  0.982422    582       1      1
# 116599 -0.022949  0.198730  0.976563    582       1      1
